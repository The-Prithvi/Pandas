# %%
import pandas as pd
dataset = {"asbf":[87,435,345], "fveggew":[55,42,234], "fewifbh":[132,324,4312]}
df = pd.DataFrame(dataset)
df
# Out:
#    asbf  fveggew  fewifbh
# 0    87       55      132
# 1   435       42      324
# 2   345      234     4312

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
df
# Out:
#     col 1   col 2  col 3  col 4
# 0        1     45    654    -56
# 1        2     46    655    -55
# 2        3     47    656    -54
# 3        4     48    657    -53
# 4        5     49    658    -52
# 5        6     50    659    -51
# 6        7     51    660    -50
# 7        8     52    661    -49
# 8        9     53    662    -48
# 9       10     54    663    -47
# 10      11     55    664    -46
# 11      12     56    665    -45

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
df.to_string()     # To print complete data frame
print(df)
# Out:
#     col 1   col 2  col 3  col 4
# 0        1     45    654    -56
# 1        2     46    655    -55
# 2        3     47    656    -54
# 3        4     48    657    -53
# 4        5     49    658    -52
# 5        6     50    659    -51
# 6        7     51    660    -50
# 7        8     52    661    -49
# 8        9     53    662    -48
# 9       10     54    663    -47
# 10      11     55    664    -46
# 11      12     56    665    -45

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
df.head()   # Prints initial 5 rows
# Out:
#    col 1   col 2  col 3  col 4
# 0       1     45    654    -56
# 1       2     46    655    -55
# 2       3     47    656    -54
# 3       4     48    657    -53
# 4       5     49    658    -52

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
df.tail()    # Prints last 5 rows
# Out:
#     col 1   col 2  col 3  col 4
# 7        8     52    661    -49
# 8        9     53    662    -48
# 9       10     54    663    -47
# 10      11     55    664    -46
# 11      12     56    665    -45

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
df[3:9]  #  DF Slicing
# Out:
#    col 1   col 2  col 3  col 4
# 3       4     48    657    -53
# 4       5     49    658    -52
# 5       6     50    659    -51
# 6       7     51    660    -50
# 7       8     52    661    -49
# 8       9     53    662    -48

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
df.columns
# Out:
# Index(['col 1 ', 'col 2', 'col 3', 'col 4'], dtype='object')

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
df["col 3"]
# Out:
# 0     654
# 1     655
# 2     656
# 3     657
# 4     658
# 5     659
# 6     660
# 7     661
# 8     662
# 9     663
# 10    664
# 11    665
# Name: col 3, dtype: int64

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
df[["col 2", "col 4"]]
# Out:
#     col 2  col 4
# 0      45    -56
# 1      46    -55
# 2      47    -54
# 3      48    -53
# 4      49    -52
# 5      50    -51
# 6      51    -50
# 7      52    -49
# 8      53    -48
# 9      54    -47
# 10     55    -46
# 11     56    -45

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
df.describe()
# Out:
#           col 1       col 2       col 3      col 4
# count  12.000000  12.000000   12.000000  12.000000
# mean    6.500000  50.500000  659.500000 -50.500000
# std     3.605551   3.605551    3.605551   3.605551
# min     1.000000  45.000000  654.000000 -56.000000
# 25%     3.750000  47.750000  656.750000 -53.250000
# 50%     6.500000  50.500000  659.500000 -50.500000
# 75%     9.250000  53.250000  662.250000 -47.750000
# max    12.000000  56.000000  665.000000 -45.000000

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
print(df['col 1'].mean())
print(df['col 1'].max())
print(df['col 1'].min())
print(df['col 1'].std())
# Out:
# 6.5
# 12
# 1
# 3.605551275463989

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
print(df[df["col 2"] == 48])
print()
print(df[df["col 2"] >= 48])
print()
print(df[df["col 2"] <= 48])
print()
print(df[df["col 2"] != 48])
# Out:
#    col 1  col 2  col 3  col 4
# 3      4     48    657    -53
#
#     col 1  col 2  col 3  col 4
# 3       4     48    657    -53
# 4       5     49    658    -52
# 5       6     50    659    -51
# 6       7     51    660    -50
# 7       8     52    661    -49
# 8       9     53    662    -48
# 9      10     54    663    -47
# 10     11     55    664    -46
# 11     12     56    665    -45
#
#    col 1  col 2  col 3  col 4
# 0      1     45    654    -56
# 1      2     46    655    -55
# 2      3     47    656    -54
# 3      4     48    657    -53
#
#     col 1  col 2  col 3  col 4
# 0       1     45    654    -56
# 1       2     46    655    -55
# 2       3     47    656    -54
# 4       5     49    658    -52
# 5       6     50    659    -51
# 6       7     51    660    -50
# 7       8     52    661    -49
# 8       9     53    662    -48
# 9      10     54    663    -47
# 10     11     55    664    -46
# 11     12     56    665    -45

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
df[["col 2", "col 3"]][df["col 2"] == 48]
# Out:
#    col 2  col 3
# 3     48    657

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
df.set_index('col 1')
# Out:
#        col 1  col 2  col 4
# col 3
# 654        1     45    -56
# 655        2     46    -55
# 656        3     47    -54
# 657        4     48    -53
# 658        5     49    -52
# 659        6     50    -51
# 660        7     51    -50
# 661        8     52    -49
# 662        9     53    -48
# 663       10     54    -47
# 664       11     55    -46
# 665       12     56    -45

# %%
import pandas as pd
dataset = pd.read_csv("CSV Sample datqa pandas.csv")
df = pd.DataFrame(dataset)
df.set_index('col 3', inplace = True)   # Inplace modifies the orignal dataframe
df
# Out:
#        col 1  col 2  col 4
# col 3
# 654        1     45    -56
# 655        2     46    -55
# 656        3     47    -54
# 657        4     48    -53
# 658        5     49    -52
# 659        6     50    -51
# 660        7     51    -50
# 661        8     52    -49
# 662        9     53    -48
# 663       10     54    -47
# 664       11     55    -46
# 665       12     56    -45

# %%
df.reset_index(inplace = True)         
df
# Out:
#     col 3  col 1  col 2  col 4
# 0     654      1     45    -56
# 1     655      2     46    -55
# 2     656      3     47    -54
# 3     657      4     48    -53
# 4     658      5     49    -52
# 5     659      6     50    -51
# 6     660      7     51    -50
# 7     661      8     52    -49
# 8     662      9     53    -48
# 9     663     10     54    -47
# 10    664     11     55    -46
# 11    665     12     56    -45

# %% [markdown]
# ## Reading CSV and its paramenters

# %%
import pandas as pd
df = pd.read_csv("CSV Pandas.csv")
df
# Out:
#        col 1       col 2  col 3  col 4  col 5  col 6
# 0     Sunday  02-01-2006     45     45     47      1
# 1     Monday  03-01-2006     87      6     11     88
# 2    Tuesday  04-01-2006     41      3     44   3212
# 3  Wednesday  05-01-2006    132      2      2     54
# 4   Thursday  06-01-2006     78     54      4      6
# 5     Friday  07-01-2006    123     54     21     28
# 6   Saturday  08-01-2006     84     84     21     52
# 7     Sunday  09-01-2006    878     47      3    965
# 8     Monday  10-01-2006     32      8      4     54

# %%
import pandas as pd
df = pd.read_csv("CSV Pandas.csv", skiprows = 2)
df
# Out:
#       Monday  03-01-2006   87   6  11    88
# 0    Tuesday  04-01-2006   41   3  44  3212
# 1  Wednesday  05-01-2006  132   2   2    54
# 2   Thursday  06-01-2006   78  54   4     6
# 3     Friday  07-01-2006  123  54  21    28
# 4   Saturday  08-01-2006   84  84  21    52
# 5     Sunday  09-01-2006  878  47   3   965
# 6     Monday  10-01-2006   32   8   4    54

# %%
import pandas as pd
df = pd.read_csv("CSV Pandas.csv", header = 2)
df
# Out:
#       Monday  03-01-2006   87   6  11    88
# 0    Tuesday  04-01-2006   41   3  44  3212
# 1  Wednesday  05-01-2006  132   2   2    54
# 2   Thursday  06-01-2006   78  54   4     6
# 3     Friday  07-01-2006  123  54  21    28
# 4   Saturday  08-01-2006   84  84  21    52
# 5     Sunday  09-01-2006  878  47   3   965
# 6     Monday  10-01-2006   32   8   4    54

# %%
import pandas as pd
df = pd.read_csv("CSV Pandas.csv", header = None)
df
# Out:
#            0           1      2      3      4      5
# 0      col 1       col 2  col 3  col 4  col 5  col 6
# 1     Sunday  02-01-2006     45     45     47      1
# 2     Monday  03-01-2006     87      6     11     88
# 3    Tuesday  04-01-2006     41      3     44   3212
# 4  Wednesday  05-01-2006    132      2      2     54
# 5   Thursday  06-01-2006     78     54      4      6
# 6     Friday  07-01-2006    123     54     21     28
# 7   Saturday  08-01-2006     84     84     21     52
# 8     Sunday  09-01-2006    878     47      3    965
# 9     Monday  10-01-2006     32      8      4     54

# %%
import pandas as pd
df = pd.read_csv("CSV Pandas.csv", names = ["1", "2", "3", "4", "5"])
df
# Out:
#                     1      2      3      4      5
# col 1           col 2  col 3  col 4  col 5  col 6
# Sunday     02-01-2006     45     45     47      1
# Monday     03-01-2006     87      6     11     88
# Tuesday    04-01-2006     41      3     44   3212
# Wednesday  05-01-2006    132      2      2     54
# Thursday   06-01-2006     78     54      4      6
# Friday     07-01-2006    123     54     21     28
# Saturday   08-01-2006     84     84     21     52
# Sunday     09-01-2006    878     47      3    965
# Monday     10-01-2006     32      8      4     54

# %%
import pandas as pd
df = pd.read_csv("CSV Pandas.csv", nrows = 6)
df
# Out:
#        col 1       col 2  col 3  col 4  col 5  col 6
# 0     Sunday  02-01-2006     45     45     47      1
# 1     Monday  03-01-2006     87      6     11     88
# 2    Tuesday  04-01-2006     41      3     44   3212
# 3  Wednesday  05-01-2006    132      2      2     54
# 4   Thursday  06-01-2006     78     54      4      6
# 5     Friday  07-01-2006    123     54     21     28

# %%
import pandas as pd
df = pd.read_csv("CSV Pandas.csv", na_values = "Sunday")
df
# Out:
#        col 1       col 2  col 3  col 4  col 5  col 6
# 0        NaN  02-01-2006     45     45     47      1
# 1     Monday  03-01-2006     87      6     11     88
# 2    Tuesday  04-01-2006     41      3     44   3212
# 3  Wednesday  05-01-2006    132      2      2     54
# 4   Thursday  06-01-2006     78     54      4      6
# 5     Friday  07-01-2006    123     54     21     28
# 6   Saturday  08-01-2006     84     84     21     52
# 7        NaN  09-01-2006    878     47      3    965
# 8     Monday  10-01-2006     32      8      4     54

# %%
import pandas as pd
df = pd.read_csv("CSV Pandas.csv", na_values = ["132", "52"])
df
# Out:
#        col 1       col 2  col 3  col 4  col 5   col 6
# 0     Sunday  02-01-2006   45.0     45     47     1.0
# 1     Monday  03-01-2006   87.0      6     11    88.0
# 2    Tuesday  04-01-2006   41.0      3     44  3212.0
# 3  Wednesday  05-01-2006    NaN      2      2    54.0
# 4   Thursday  06-01-2006   78.0     54      4     6.0
# 5     Friday  07-01-2006  123.0     54     21    28.0
# 6   Saturday  08-01-2006   84.0     84     21     NaN
# 7     Sunday  09-01-2006  878.0     47      3   965.0
# 8     Monday  10-01-2006   32.0      8      4    54.0

# %%
import pandas as pd
# data = [("fewf", "reqw","fewf","fewf","fewf","fewf","fewf",), ("hgdgfd", "wtret")]
data = {
    "col 1": [1,2,5,8,4,6,3,5,9,7],
    "col 2": [1,2,5,8,4,6,3,5,9,7],
    "col 3": [1,2,5,8,4,6,3,5,9,7]
}
df = pd.DataFrame(data)
df
df.to_csv("writeTo_csv.csv")

# %%
import pandas as pd
# data = [("fewf", "reqw","fewf","fewf","fewf","fewf","fewf",), ("hgdgfd", "wtret")]
data = {
    "col 1": [1,2,5,8,4,6,3,5,9,7],
    "col 2": [1,2,5,8,4,6,3,5,9,7],
    "col 3": [1,2,5,8,4,6,3,5,9,7]
}
df = pd.DataFrame(data)
df
df.to_csv("write_csv_index=False.csv", index = False)

# %%
import pandas as pd
# data = [("fewf", "reqw","fewf","fewf","fewf","fewf","fewf",), ("hgdgfd", "wtret")]
data = {
    "col 1": [1,2,5,8,4,6,3,5,9,7],
    "col 2": [1,2,5,8,4,6,3,5,9,7],
    "col 3": [1,2,5,8,4,6,3,5,9,7]
}
df = pd.DataFrame(data)
df.to_csv("write_csv_coulumns.csv", columns =["col 2", "col 3"])

# %%
import pandas as pd
# data = [("fewf", "reqw","fewf","fewf","fewf","fewf","fewf",), ("hgdgfd", "wtret")]
data = {
    "col 1": [1,2,5,8,4,6,3,5,9,7],
    "col 2": [1,2,5,8,4,6,3,5,9,7],
    "col 3": [1,2,5,8,4,6,3,5,9,7]
}
df = pd.DataFrame(data)
df.to_csv("write_csv_header=False.csv", header = False)

# %% [markdown]
# ## Reading Excel

# %%
import pandas as pd
df = pd.read_excel("Financial Sample.xlsx", "Sheet1")
df = df.to_string()
print(df)
# Out:
#              Column1                   Column2    Column3 Column4  Column5  Column6  Column7   Column8
# 0         Government                    Canada  Carretera     NaN   1618.5        3       20   32370.0
# 1         Government                   Germany  Carretera     NaN   1321.0        3       20   26420.0
# 2          Midmarket                    France  Carretera     NaN   2178.0        3       15   32670.0
# 3          Midmarket                   Germany  Carretera     NaN    888.0        3       15   13320.0
# 4          Midmarket                    Mexico  Carretera     NaN   2470.0        3       15   37050.0
# 5         Government                   Germany  Carretera     NaN   1513.0        3      350  529550.0
# 6          Midmarket                   Germany    Montana     NaN    921.0        5       15   13815.0
# 7   Channel Partners                    Canada    Montana     NaN   2518.0        5       12   30216.0
# ...

# %%
import pandas as pd
def func1(cell):
    if cell == "Mexico":
        return "Mex City"
    return cell
df = pd.read_excel("Financial Sample.xlsx", "Sheet1", converters = {
    "Column2": func1
})
print(df)
# Out:
#              Column1                   Column2    Column3 Column4  Column5  \
# 0         Government                    Canada  Carretera     NaN   1618.5
# 1         Government                   Germany  Carretera     NaN   1321.0
# 2          Midmarket                    France  Carretera     NaN   2178.0
# 3          Midmarket                   Germany  Carretera     NaN    888.0
# 4          Midmarket                  Mex City  Carretera     NaN   2470.0
# ..               ...                       ...        ...     ...      ...
# 56        Government                    France       Velo     Low    639.0
# 57        Government                    Canada        VTT     Low   1326.0
# 58  Channel Partners  United States of America  Carretera     Low   1858.0
# 59        Government                  Mex City  Carretera     Low   1210.0
# 60        Government  United States of America  Carretera     Low   2529.0
#
#     Column6  Column7   Column8
# 0         3       20   32370.0
# ...

# %% [markdown]
# ## Writing Excel

# %%
import pandas as pd
data = {
    "col 1": [1,2,5,8,4,6,3,5,9,7],
    "col 2": [1,2,5,8,4,6,3,5,9,7],
    "col 3": [1,2,5,8,4,6,3,5,9,7]
}
df = pd.DataFrame(data)
df.to_excel("write_excel.xlsx", "Sheet 1")

# %%
import pandas as pd
data = {
    "col 1": [1,2,5,8,4,6,3,5,9,7],
    "col 2": [1,2,5,8,4,6,3,5,9,7],
    "col 3": [1,2,5,8,4,6,3,5,9,7]
}
df = pd.DataFrame(data)
df.to_excel("write_excel_startrow.xlsx", "Sheet 1", startrow = 3)

# %%
  import pandas as pd
data = {
    "col 1": [1,2,5,8,4,6,3,5,9,7],
    "col 2": [1,2,5,8,4,6,3,5,9,7],
    "col 3": [1,2,5,8,4,6,3,5,9,7]
}
df = pd.DataFrame(data)
df.to_excel("write_excel_index=false.xlsx", "Sheet 1", index = False)

# %%
import pandas as pd
df1 = pd.read_excel("SampleData1.xlsx", "Sheet1")
df2 = pd.read_excel("SampleData2.xlsx", "Sheet1")
with pd.ExcelWriter("Combine Data in same file sepearated by sheets.xlsx") as writer:
    df1.to_excel(writer, "Sheet1")
    df2.to_excel(writer, "Sheet2")

# %% [markdown]
# ## Handle Missing Data

# %%
import pandas as pd 
df = pd.read_csv("Missing Data.csv")
df
# Out:
#       col 1       col 2  col 3  col 4  col 5   col 6
# 0    Sunday  02-01-2006   45.0   45.0   47.0     1.0
# 1    Monday  03-01-2006   87.0    6.0   11.0    88.0
# 2   Tuesday  04-01-2006   41.0    3.0    NaN  3212.0
# 3       NaN  05-01-2006  132.0    2.0    2.0    54.0
# 4  Thursday         NaN   78.0   54.0    4.0     6.0
# 5    Friday  07-01-2006  123.0   54.0   21.0    28.0
# 6  Saturday  08-01-2006   84.0    NaN   21.0    52.0
# 7    Sunday  09-01-2006    NaN   47.0    3.0   965.0
# 8    Monday  10-01-2006   32.0    8.0    4.0     NaN

# %%
import pandas as pd 
df = pd.read_csv("Missing Data.csv")
# df.fillna("Data Not Available", inplace = True)
df.fillna(0, inplace = True)
df
# Out:
#       col 1       col 2  col 3  col 4  col 5   col 6
# 0    Sunday  02-01-2006   45.0   45.0   47.0     1.0
# 1    Monday  03-01-2006   87.0    6.0   11.0    88.0
# 2   Tuesday  04-01-2006   41.0    3.0    0.0  3212.0
# 3         0  05-01-2006  132.0    2.0    2.0    54.0
# 4  Thursday           0   78.0   54.0    4.0     6.0
# 5    Friday  07-01-2006  123.0   54.0   21.0    28.0
# 6  Saturday  08-01-2006   84.0    0.0   21.0    52.0
# 7    Sunday  09-01-2006    0.0   47.0    3.0   965.0
# 8    Monday  10-01-2006   32.0    8.0    4.0     0.0

# %%
import pandas as pd 
df = pd.read_csv("Missing Data.csv")
df.fillna({
    "col 2": "01-01-0001",
    "col 1": "N/A",
    "col 4": 55
}, inplace = True)
df
# Out:
#       col 1       col 2  col 3  col 4  col 5   col 6
# 0    Sunday  02-01-2006   45.0   45.0   47.0     1.0
# 1    Monday  03-01-2006   87.0    6.0   11.0    88.0
# 2   Tuesday  04-01-2006   41.0    3.0    NaN  3212.0
# 3       N/A  05-01-2006  132.0    2.0    2.0    54.0
# 4  Thursday  01-01-0001   78.0   54.0    4.0     6.0
# 5    Friday  07-01-2006  123.0   54.0   21.0    28.0
# 6  Saturday  08-01-2006   84.0   55.0   21.0    52.0
# 7    Sunday  09-01-2006    NaN   47.0    3.0   965.0
# 8    Monday  10-01-2006   32.0    8.0    4.0     NaN

# %%
import pandas as pd 
df = pd.read_csv("Missing Data.csv")
# df.fillna(method = "ffill", inplace = True)
df.ffill(inplace = True)
df
# Out:
#       col 1       col 2  col 3  col 4  col 5   col 6
# 0    Sunday  02-01-2006   45.0   45.0   47.0     1.0
# 1    Monday  03-01-2006   87.0    6.0   11.0    88.0
# 2   Tuesday  04-01-2006   41.0    3.0   11.0  3212.0
# 3   Tuesday  05-01-2006  132.0    2.0    2.0    54.0
# 4  Thursday  05-01-2006   78.0   54.0    4.0     6.0
# 5    Friday  07-01-2006  123.0   54.0   21.0    28.0
# 6  Saturday  08-01-2006   84.0   54.0   21.0    52.0
# 7    Sunday  09-01-2006   84.0   47.0    3.0   965.0
# 8    Monday  10-01-2006   32.0    8.0    4.0   965.0

# %%
import pandas as pd 
df = pd.read_csv("Missing Data.csv")
# df.fillna(method = "ffill", inplace = True)
df.bfill(inplace = True)
df
# Out:
#       col 1       col 2  col 3  col 4  col 5   col 6
# 0    Sunday  02-01-2006   45.0   45.0   47.0     1.0
# 1    Monday  03-01-2006   87.0    6.0   11.0    88.0
# 2   Tuesday  04-01-2006   41.0    3.0    2.0  3212.0
# 3  Thursday  05-01-2006  132.0    2.0    2.0    54.0
# 4  Thursday  07-01-2006   78.0   54.0    4.0     6.0
# 5    Friday  07-01-2006  123.0   54.0   21.0    28.0
# 6  Saturday  08-01-2006   84.0   47.0   21.0    52.0
# 7    Sunday  09-01-2006   32.0   47.0    3.0   965.0
# 8    Monday  10-01-2006   32.0    8.0    4.0     NaN

# %%
import pandas as pd 
df = pd.read_csv("Missing Data.csv")
df.interpolate(method='linear', inplace = True)
df
# Out:
# C:\Users\prith\AppData\Local\Temp\ipykernel_1868\3782668989.py:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear', inplace = True)
#       col 1       col 2  col 3  col 4  col 5   col 6
# 0    Sunday  02-01-2006   45.0   45.0   47.0     1.0
# 1    Monday  03-01-2006   87.0    6.0   11.0    88.0
# 2   Tuesday  04-01-2006   41.0    3.0    6.5  3212.0
# 3       NaN  05-01-2006  132.0    2.0    2.0    54.0
# 4  Thursday         NaN   78.0   54.0    4.0     6.0
# 5    Friday  07-01-2006  123.0   54.0   21.0    28.0
# 6  Saturday  08-01-2006   84.0   50.5   21.0    52.0
# 7    Sunday  09-01-2006   58.0   47.0    3.0   965.0
# 8    Monday  10-01-2006   32.0    8.0    4.0   965.0

# %% [markdown]
# ## Useful Methods

# %%
import pandas as pd
df = pd.read_csv("CSV Pandas.csv")
df
# Out:
#        col 1       col 2  col 3  col 4  col 5  col 6
# 0     Sunday  02-01-2006     45     45     47      1
# 1     Monday  03-01-2006     87      6     11     88
# 2    Tuesday  04-01-2006     41      3     44   3212
# 3  Wednesday  05-01-2006    132      2      2     54
# 4   Thursday  06-01-2006     78     54      4      6
# 5     Friday  07-01-2006    123     54     21     28
# 6   Saturday  08-01-2006     84     84     21     52
# 7     Sunday  09-01-2006    878     47      3    965
# 8     Monday  10-01-2006     32      8      4     54

# %%
df = pd.read_csv("CSV Pandas.csv")
df.replace(88, 100, inplace = True)
df
# Out:
#        col 1       col 2  col 3  col 4  col 5  col 6
# 0     Sunday  02-01-2006     45     45     47      1
# 1     Monday  03-01-2006     87      6     11    100
# 2    Tuesday  04-01-2006     41      3     44   3212
# 3  Wednesday  05-01-2006    132      2      2     54
# 4   Thursday  06-01-2006     78     54      4      6
# 5     Friday  07-01-2006    123     54     21     28
# 6   Saturday  08-01-2006     84     84     21     52
# 7     Sunday  09-01-2006    878     47      3    965
# 8     Monday  10-01-2006     32      8      4     54

# %%
df = pd.read_csv("CSV Pandas.csv")
df.replace([21,28,"Sunday"], 100, inplace = True)
df
# Out:
#        col 1       col 2  col 3  col 4  col 5  col 6
# 0        100  02-01-2006     45     45     47      1
# 1     Monday  03-01-2006     87      6     11     88
# 2    Tuesday  04-01-2006     41      3     44   3212
# 3  Wednesday  05-01-2006    132      2      2     54
# 4   Thursday  06-01-2006     78     54      4      6
# 5     Friday  07-01-2006    123     54    100    100
# 6   Saturday  08-01-2006     84     84    100     52
# 7        100  09-01-2006    878     47      3    965
# 8     Monday  10-01-2006     32      8      4     54

# %%
import pandas as pd
df = pd.read_csv("CSV Pandas.csv")
df.replace({
    # "col 3": 878,
    "col 3": [878, 123],
    "col 1": 'Friday',
    "col 5": 44
}, "Replace Value", inplace = True)
df
# Out:
#            col 1       col 2          col 3  col 4          col 5  col 6
# 0         Sunday  02-01-2006             45     45             47      1
# 1         Monday  03-01-2006             87      6             11     88
# 2        Tuesday  04-01-2006             41      3  Replace Value   3212
# 3      Wednesday  05-01-2006            132      2              2     54
# 4       Thursday  06-01-2006             78     54              4      6
# 5  Replace Value  07-01-2006  Replace Value     54             21     28
# 6       Saturday  08-01-2006             84     84             21     52
# 7         Sunday  09-01-2006  Replace Value     47              3    965
# 8         Monday  10-01-2006             32      8              4     54

# %%
import pandas as pd
df = pd.read_csv("CSV Pandas.csv")
df.replace({
    # [878, 123]: "No Data Available",
     123: "No Data Available",
    'Friday': "Sunday",
    44: 99999 }, inplace = True)
df
# Out:
#        col 1       col 2              col 3  col 4  col 5  col 6
# 0     Sunday  02-01-2006                 45     45     47      1
# 1     Monday  03-01-2006                 87      6     11     88
# 2    Tuesday  04-01-2006                 41      3  99999   3212
# 3  Wednesday  05-01-2006                132      2      2     54
# 4   Thursday  06-01-2006                 78     54      4      6
# 5     Sunday  07-01-2006  No Data Available     54     21     28
# 6   Saturday  08-01-2006                 84     84     21     52
# 7     Sunday  09-01-2006                878     47      3    965
# 8     Monday  10-01-2006                 32      8      4     54

# %%
import pandas as pad
df = pd.read_csv("CSV Pandas.csv")
df.replace({28,21,2,54}, {9999,8888,7777,6666}, inplace = True)
df
# Out:
#        col 1       col 2  col 3  col 4  col 5  col 6
# 0     Sunday  02-01-2006     45     45     47      1
# 1     Monday  03-01-2006     87      6     11     88
# 2    Tuesday  04-01-2006     41      3     44   3212
# 3  Wednesday  05-01-2006    132   8888   8888   9999
# 4   Thursday  06-01-2006     78   9999      4      6
# 5     Friday  07-01-2006    123   9999   6666   7777
# 6   Saturday  08-01-2006     84     84   6666     52
# 7     Sunday  09-01-2006    878     47      3    965
# 8     Monday  10-01-2006     32      8      4   9999

# %%
import pandas as pad
df = pd.read_csv("CSV Pandas.csv")
# df.replace('[A-Za-z]', "Regex Used",regex = True , inplace = True)//
# Out:
#        col 1       col 2  col 3  col 4  col 5  col 6
# 0     Sunday  02-01-2006     45     45     47      1
# 1     Monday  03-01-2006     87      6     11     88
# 2    Tuesday  04-01-2006     41      3     44   3212
# 3  Wednesday  05-01-2006    132      2      2     54
# 4   Thursday  06-01-2006     78     54      4      6
# 5     Friday  07-01-2006    123     54     21     28
# 6   Saturday  08-01-2006     84     84     21     52
# 7     Sunday  09-01-2006    878     47      3    965
# 8     Monday  10-01-2006     32      8      4     54

# %% [markdown]
# ## Group By

# %%
import pandas as pd
df = pd.read_csv("CSV Pandas.csv")
g = df.groupby("col 1")
for data, dataFrame in g:
    print(data)
    print(dataFrame)
# Out:
# Friday
#     col 1       col 2  col 3  col 4  col 5  col 6
# 5  Friday  07-01-2006    123     54     21     28
# Monday
#     col 1       col 2  col 3  col 4  col 5  col 6
# 1  Monday  03-01-2006     87      6     11     88
# 8  Monday  10-01-2006     32      8      4     54
# Saturday
#       col 1       col 2  col 3  col 4  col 5  col 6
# 6  Saturday  08-01-2006     84     84     21     52
# Sunday
#     col 1       col 2  col 3  col 4  col 5  col 6
# 0  Sunday  02-01-2006     45     45     47      1
# 7  Sunday  09-01-2006    878     47      3    965
# Thursday
#       col 1       col 2  col 3  col 4  col 5  col 6
# 4  Thursday  06-01-2006     78     54      4      6
# Tuesday
#      col 1       col 2  col 3  col 4  col 5  col 6
# 2  Tuesday  04-01-2006     41      3     44   3212
# Wednesday
#        col 1       col 2  col 3  col 4  col 5  col 6
# 3  Wednesday  05-01-2006    132      2      2     54

# %% [markdown]
# ## Concat

# %%
import pandas as pd
df1 = pd.read_csv("CSV Pandas.csv")
df2 = pd.read_excel("Financial Sample.xlsx", "Sheet1")
df3 = pd.concat([df1, df2], ignore_index = True)
df3
# Out:
#         col 1       col 2  col 3  col 4  col 5   col 6           Column1  \
# 0      Sunday  02-01-2006   45.0   45.0   47.0     1.0               NaN
# 1      Monday  03-01-2006   87.0    6.0   11.0    88.0               NaN
# 2     Tuesday  04-01-2006   41.0    3.0   44.0  3212.0               NaN
# 3   Wednesday  05-01-2006  132.0    2.0    2.0    54.0               NaN
# 4    Thursday  06-01-2006   78.0   54.0    4.0     6.0               NaN
# ..        ...         ...    ...    ...    ...     ...               ...
# 65        NaN         NaN    NaN    NaN    NaN     NaN        Government
# 66        NaN         NaN    NaN    NaN    NaN     NaN        Government
# 67        NaN         NaN    NaN    NaN    NaN     NaN  Channel Partners
# 68        NaN         NaN    NaN    NaN    NaN     NaN        Government
# 69        NaN         NaN    NaN    NaN    NaN     NaN        Government
#
#                      Column2    Column3 Column4  Column5  Column6  Column7  \
# ...
